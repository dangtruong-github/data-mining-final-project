# %%
import pandas as pd

# %%
df_orig = pd.read_csv("./11_tags_grouping_after_annotated_part_1.csv")

df_to_combine = pd.read_excel("./11_tags_have_been_annotated.xlsx")

# %%
df_to_combine
# Out:
#         ID                                        Description  depth  \
# 0     68.0  blair has her life planned out, she's got ever...    1.0
# 1    134.0  Tác giả: Sướng Ái\n    Tình trạng: Hoàn\n    C...    1.0
# 2    136.0  Thể loại: Nguyên sang, Đam mỹ, Cận đại , Hiện ...    1.0
# 3    147.0  Book Two in the I Am Not A Prostitute series.\...    1.0
# 4    175.0  -Nơi tổng hợp 7749 thứ về SevenAU, chủ yếu là ...    1.0
# 5    248.0  Mia Gibson and Hunter James were always meant ...    1.0
# 6    317.0  Trường THPT XYZ vốn là trường chuyên của thành...    1.0
# 7    455.0  Tên gốc: \n    Thể loại: Đam Mỹ, toàn tức võng...    2.0
# 8    511.0    | If only the clockworks could speak, I woul...    1.0
# 9    540.0  Kino and his friends go on a summer roadtripbu...    1.0
# 10  1247.0  Hu Yaoyao was originally a little fox who had ...    2.0
# 11  1409.0  "Lovers come and haters go"\n    \n    Cover b...    2.0
# 12  1998.0  Có thể nhiều người bạn thân, quen đọc xong fic...    0.0
# ...

# %%
for i in range(len(df_to_combine)):
    id_story = df_to_combine.at[i, "ID"]
    
    index_df_orig = df_orig.loc[df_orig["ID"] == id_story]
    
    if index_df_orig.empty:
        print("here")
        continue
    
    index_df_orig_index = index_df_orig.index[0]
    
    
    df_orig.at[index_df_orig_index, "story_tags_list"] = df_to_combine.at[i, "story_tags_list"]

# %%
df_orig
# Out:
#         ID                                        Description  depth  \
# 0        0  Cuộc sống và chuyện tình cảm của 12 chòm sao t...      0
# 1        1  Thế kỷ 21, nàng là một trong những người nổi t...      0
# 2        2  Đây là những gì mình sưu tầm được. Vì khá thíc...      0
# 3        3  Tình yêu của một tên giết người dưới góc nhìn ...      0
# 4        4  Hán Việt: Tuyệt vọng giáo thất\n    \n    Tác ...      0
# ...    ...                                                ...    ...
# 2885  2970  ta chia tay vào một ngày lặng gió\nta tái ngộ ...      1
# 2886  2971  Anh là nhà của em, mỗi khi mệt mỏi, chỉ cần nh...      1
# 2887  2972  Maybee : OOC !!\nLệch Nguyên Tác !!!\nDo not đ...      1
# 2888  2973   Author:@ElinaDepChai (Wattpad)\n     Fandom :...      1
# 2889  2974  Trong một hành tinh to to lại có một quốc gia ...      1
#
#                story_tags_list  \
# 0                    [2, 3, 3]
# 1                    [2, 2, 2]
# 2                          [2]
# ...

# %%
df_orig.to_csv("./12_group_last_time.csv", index=False)

# %%
df_orig.loc[df_orig["ID"] == 455, "story_tags_list"]
# Out:
# 446    ['dammy']
# Name: story_tags_list, dtype: object
