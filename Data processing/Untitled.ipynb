# %%
import pandas as pd

# %%
df = pd.read_csv("./data_no_freq.csv")

# %%
df["text"] = df_old["Description"]

# %%
df_loc = df.loc[df["id"].isin(list(df.loc[(df["1"] == False) & (df["4"] == True)]["id"].astype(int)))]

# %%
df_old = pd.read_csv("./data_cleaning/4_combine_description_and_features.csv")

# %%
df_old.loc[df_old["ID"].isin(list(df.loc[(df["1"] == False) & (df["4"] == True)]["id"].astype(int)))]
# Out:
#         ID                                        Description  depth  \
# 5        5  Tên Hán Việt: Tàm Thực\nTác giả: Tiểu Yêu Tử\n...      0
# 16      16  Tên: Ngã tại phạm tội hiện tràng lý liêu hung ...      0
# 20      20  ~Chuyển ver~\n    \n    Nguồn:santruyen\n    \...      1
# 26      26  Tác giả: Thanh Tôn\n    \n    Số chương: 191 c...      1
# 27      27  《𝐻𝑎𝑖𝐾𝑎𝑣𝑒ℎ 𝑙𝑎̀ 𝑡ℎ𝑎̣̂𝑡, 𝑡𝑜̂𝑖 𝑙𝑎̀ 𝑔𝑖𝑎̉》\n    \n  ...      1
# ...    ...                                                ...    ...
# 2954  2954  Những câu chuyện ngắn như một lát cắt trong đờ...      1
# 2964  2964  Văn ngôn còn hơi non nớt \n    debut : 26/5/20...      1
# 2966  2966  Writer (tác giả): JinForLife\n    \n    Transl...      1
# 2969  2969  Writer (tác giả): JinForLife\n\nTranslator (Ng...      1
# 2970  2970  ta chia tay vào một ngày lặng gió\nta tái ngộ ...      1
#
#                                         story_tags_list  \
# 5     ['biếnthái', 'bl', 'boylove', 'bíẩn', 'bệnhkiề...
# ...

# %%
df_loc.to_csv("./to_analyze_later.csv", index=False)
