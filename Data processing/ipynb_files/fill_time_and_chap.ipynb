# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./cleaned_stories.csv")

# %%
df
# Out:
#         ID  depth                                    story_tags_list  \
# 0        0      0  ['siêunhiên', 'thienbinh', 'xunu', 'yết-xử', '...
# 1        1      0  ['bíẩn', 'dieutra', 'xuyênkhông', 'thriller', ...
# 2        2      0                         ['fbi', 'cryptic', 'bíẩn']
# 3        3      0  ['love', 'kinhdi', 'thithe', 'bíẩn', 'máu', 'h...
# 4        4      0  ['khoahọcviễntưởng', 'kinhdi', 'edit', 'bíẩn',...
# ...    ...    ...                                                ...
# 2970  2970      1  ['1shot', 'chill', 'oneshot', 'taeguk', 'taehy...
# 2971  2971      1  ['chill', 'healing', 'hyunho', 'hyunjin', 'kno...
# 2972  2972      1  ['bllk', 'bluelock', 'chill', 'kainess', 'kais...
# 2973  2973      1  ['anime', 'bias', 'charxreader', 'chill', 'fan...
# 2974  2974      1  ['12chomsao', 'bachduong', 'bảobình', 'bựa', '...
#
#                                               cover_img  \
# 0     https://img.wattpad.com/cover/51678600-512-k93...
# ...

# %%
chaps_and_time = df[["Chương", "Thời gian"]]

# %%
full_data = chaps_and_time[(chaps_and_time["Chương"].notnull()) & (chaps_and_time["Thời gian"].notnull())]

# %%
full_data
# Out:
#       Chương  Thời gian
# 60       5.0      991.0
# 61      13.0      237.0
# 62      56.0      326.0
# 63      59.0      745.0
# 64      63.0     1209.0
# ...      ...        ...
# 2593    52.0      227.0
# 2594    45.0      293.0
# 2597    87.0      448.0
# 2598    14.0      349.0
# 2599   200.0     1914.0
#
# [1455 rows x 2 columns]

# %%
full_data.plot()
# Out:
# <Axes: >
